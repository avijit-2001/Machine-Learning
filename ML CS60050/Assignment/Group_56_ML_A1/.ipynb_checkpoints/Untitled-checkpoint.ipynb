# %%
import pandas as pd
import numpy as np
from __future__ import print_function
import matplotlib.pyplot as plt

# %%
header = ["age","workclass","fnlwgt","education","education_num","marital_status","occupation","relationship","race","sex","capital_gain","capital_loss","hours_per_week","native_country","target"]

# %%
df = pd.read_csv("adult.csv", header = None)

# %%
df.columns = header

# %%
df.head(5)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
def handle_missing_data(df):
    
    """
    This function will replace all ' ?' values from data frame with maximum occuring
    from attribute from that particular attribute
    """
    for col in df.columns:
        col_set = df[col]
        counts = {}
        cnt = 0
        for attribute in col_set.unique():
            counts[attribute] = 0
            if attribute == ' ?':
                cnt += 1
        if not cnt:
            continue
        for attribute in col_set:
            counts[attribute]+=1
        max_freq = ' ?'
        for attribute in col_set:
            if counts[max_freq]<counts[attribute]:
                max_freq = attribute
        for i in range(len(df[col])):
            if df[col][i] == ' ?':
                df[col][i] = max_freq
    return df

# %%
df = handle_missing_data(df) #  Missing value modified
# Out:
# <ipython-input-183-be94e4e7226c>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][i] = max_freq

# %%
def split_data_random(df):
    shuffle_df = df.sample(frac = 1)
    train_size = int(0.8*len(df))
    train = shuffle_df[:train_size]
    test = shuffle_df[train_size:]
    
    return train, test

# %%
def split_data_for_pruning(df):
    shuffle_df = df.sample(frac = 1)
    train_size = int(0.6*len(df))
    val_size = int(0.8*len(df))
    train = shuffle_df[:train_size]
    test = shuffle_df[train_size:val_size]
    val = shuffle_df[val_size:]
    
    return train, val, test

# %%
train, test = split_data_random(df)

# %%
def newList_from_df(df):
    newList = []
    for i in range(len(df)):
        blankList = []
        newList.append(blankList)
    i = 0
    for col in df.columns:
        i = 0
        for attribute in df[col]:
            newList[i].append(attribute)
            i = i + 1
    return newList

# %%
training_data = newList_from_df(train)
testing_data = newList_from_df(test)

# %%
def unique_vals(rows,col):
    """Find the unique values for a column in a dataset"""
    return set([row[col] for row in rows])

# %%
def class_counts(rows):
    """Counts the number of each type of example in a dataset"""
    counts = {}
    for row in rows:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label]+=1
    return counts

# %%
def is_numeric(value):
    """Test if a value is of type numeric"""
    return isinstance(value, int) or isinstance(value, float)

# %%
class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 13 for native_country) and a
    'column value' (e.g., United States). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question.
    """
    
    def __init__(self, column, value):
        self.column = column
        self.value = value
    def match(self, example):
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value
    
    def __repr__(self):
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s ?" %(header[self.column],condition,str(self.value))

# %%
def partition(rows,question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [],[]
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
def gini(rows):
    """Calculate the Gini Impurity for a list of rows """
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl]/(float(len(rows)))
        impurity -= prob_of_lbl**2
    return impurity

# %%
def info_gain(left, right, curr):
    prob_left = float(len(left)/(len(left)+len(right)))
    return curr - prob_left*gini(left) - (1 - prob_left)*gini(right)

# %%
true_rows, false_rows = partition(training_data,Question(3,' Bachelors'))
info_gain(true_rows,false_rows, gini(training_data))
# Out:
# 0.011319264357292802

# %%
def find_best_split(rows):
    """
    finds the best split by iterating over all possible feature/values
    and calculating the information gain.
    """
    
    best_gain = 0.0 # keep track of the best information gain
    best_question = None # keep a track for best question corresponding to best_gain
    
    current_uncertinity = gini(rows)    
    for col in range(len(rows[0]) - 1):
        
        values = unique_vals(rows,col)
        
        for val in values:
            
            ques = Question(col,val)
            true_rows, false_rows = partition(rows, ques)
            
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue
                
            gain = info_gain(true_rows, false_rows, current_uncertinity)
            
            if gain >= best_gain:
                best_gain, best_question = gain, ques
    return best_gain, best_question

# %%
# best_gain, best_question = find_best_split(training_data)
# best_question

# %%
class Leaf:
    """
    A Leaf node classification data.
    
    This holds a dictionary of class e.g ">=50K" --> number of times it
    appears in the rows from the training data that reach this leaf.
    """
    
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    """
    A Decision Node asks a question.
    
    This holds a reference to the question, and to the two child nodes.
    """
    
    def __init__(self, question, true_branch, false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch
        self.count = {' >50K':0, ' <=50K':0}

# %%
def build_tree(rows):
    
    gain, question = find_best_split(rows)
    
    """
    If there is no gain in spliting then juts make it a Leaf
    """
    if gain == 0:
        return Leaf(rows)
    
    true_rows, false_rows = partition(rows, question)
    
    """
    recuresively build tree true and false branch
    """
    true_branch = build_tree(true_rows)
    false_branch = build_tree(false_rows)
    
    return Decision_Node(question, true_branch, false_branch)

# %%
def build_tree_max_depth(rows,curr_depth, max_depth):
    
    gain, question = find_best_split(rows)
    
    """
    If there is no gain in spliting then juts make it a Leaf
    or if it reaches the max_depth make it a leaf
    """
    if gain == 0 or curr_depth == max_depth:
        return Leaf(rows)
    
    true_rows, false_rows = partition(rows, question)
    
    """
    recuresively build tree true and false branch
    """
    true_branch = build_tree_max_depth(true_rows, curr_depth + 1, max_depth)
    false_branch = build_tree_max_depth(false_rows, curr_depth + 1, max_depth)
    
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    
    if isinstance(node, Leaf):
        print(spacing + "Predict",node.predictions)
        return 
    
    print(spacing + str(node.question))
    
    print(spacing + '--> True')
    left_height = print_tree(node.true_branch, spacing + " ")
    
    print(spacing + '--> False')
    right_height = print_tree(node.false_branch, spacing + " ")

# %%
def classify(row,node):
    
    if isinstance(node,Leaf):
        return node.predictions
    
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
def update_decision_count(node):
    
    """
    This function will update_decision_count for a given tree, i.e the 
    number of >50K and <=50K correspondind to subtree of each node
    """
    
    if isinstance(node, Leaf):
        
        leaf_gT, leaf_lT = 0, 0
        if ' >50K' in node.predictions:
            leaf_gT = node.predictions[' >50K']
        if ' <=50K' in node.predictions:
            leaf_lT = node.predictions[' <=50K']
        return leaf_gT, leaf_lT;
    
    true_gT, true_lT = update_decision_count(node.true_branch)
    false_gT, false_lT = update_decision_count(node.false_branch)
    
    node.count[' >50K'] = true_gT + false_gT
    node.count[' <=50K'] = true_lT + false_lT
    
    return node.count[' >50K'], node.count[' <=50K']

# %%
def predict_accuracy(my_tree,testing_data):
    correct_count = 0.0
    for row in testing_data:
        prediction = classify(row,my_tree)
        list_pred = list(prediction)
        
        cnt_gT = 0.0
        cnt_lT = 0.0
        
        if len(list_pred) == 2:
            cnt_lT+=prediction[' <=50K']
            cnt_gT+=prediction[' >50K']
        else:
            if ' <=50K' in list_pred:
                cnt_lT+=prediction[' <=50K']
            elif ' >50K' in list_pred:
                cnt_gT+=prediction[' >50K']   
        
        if ' >50K' == row[-1]:
            correct_count += int((cnt_gT)/(cnt_lT+cnt_gT))
        elif ' <=50K' == row[-1]:
            correct_count += int((cnt_lT)/(cnt_lT+cnt_gT))
        
    return 100.0*(correct_count/len(testing_data))

# %%
def tree_depth(node):
    
    if isinstance(node,Leaf):
        return 1
    return 1 + max(tree_depth(node.true_branch), tree_depth(node.false_branch))

# %%
def return_best_tree(df):
    
    best_tree = None
    best_depth = 0.0
    sum_of_accuracy = 0.0
    best_accuracy = 0.0
    
    plot_x = []
    plot_y = []
    
    for i in range(10):
        
        """
        Keep taking input unless maximum accuracy achived
        """
#         max_depth = int(input("Give a max_depth:"))
        max_depth = -1;
        
#         train, test = split_data_random(df)
        train, test = split_data_random(df[:4000]) # uncomment to use for lesser data as 40K of instances will take huge time 
        training_data = newList_from_df(train)
        testing_data = newList_from_df(test)
        
        my_tree_ = build_tree(training_data)
        
        new_accuracy = predict_accuracy(my_tree_,testing_data)
                
        sum_of_accuracy += new_accuracy
        
        plot_x.append(tree_depth(my_tree_))
        plot_y.append(new_accuracy)
        
        if new_accuracy > best_accuracy:
            best_accuracy = new_accuracy
            best_tree = my_tree_
            
        
    return best_tree, (sum_of_accuracy)/10.0, plot_x,plot_y

# %%
# 1.Best Tree

# %%
best_tree, average_accuracy, plot_x, plot_y = return_best_tree(df)
update_decision_count(best_tree)
print("")
print("Best Depth = " + str(tree_depth(best_tree))+"," + "Best Accuracy = "+ str(predict_accuracy(best_tree,training_data)))
# Out:
# Best Depth = 33,Best Accuracy = 81.43427518427518

# %%
print(plot_x, plot_y)
# Out:
# [31, 37, 33, 36, 29, 33, 39, 30, 35, 35] [78.25, 79.5, 81.125, 79.75, 77.25, 79.125, 79.875, 79.75, 77.875, 80.375]

# %%
def plot_graph(plot_x, plot_y):
    """
    Here Plot of Depth Vs Accuracy 
    """
    plot = []
    for i in range(len(plot_x)):
        plot.append((plot_x[i],plot_y[i])) 
    plot.sort()
    
    for i in range(len(plot)):
        plot_x[i] = plot[i][0]
        plot_y[i] = plot[i][1]
    
    plt.plot(plot_x,plot_y)
    plt.xlabel('Depth of the Tree')
    plt.ylabel('Achieved Accuracy')
    plt.title('Depth Vs Accuracy')
    plt.show()

# %%
plot_graph(plot_x,plot_y)

# %%
print_tree(best_tree)
# Out:
# Is marital_status ==  Married-civ-spouse ?
# --> True
#  Is education_num >= 12 ?
#  --> True
#   Is capital_gain >= 5178 ?
#   --> True
#    Predict {' >50K': 76}
#   --> False
#    Is capital_loss >= 1848 ?
#    --> True
#     Predict {' >50K': 50}
#    --> False
#     Is occupation ==  Exec-managerial ?
#     --> True
#      Is hours_per_week >= 25 ?
#      --> True
#       Is fnlwgt >= 454508 ?
#       --> True
#        Is native_country ==  United-States ?
#        --> True
#         Predict {' <=50K': 2}
#        --> False
#         Predict {' >50K': 1}
#       --> False
#        Is capital_gain >= 5013 ?
#        --> True
#         Predict {' <=50K': 1}
#        --> False
#         Is age >= 90 ?
#         --> True
#          Predict {' <=50K': 1}
#         --> False
#          Is fnlwgt >= 71738 ?
#          --> True
#           Is race ==  Black ?
#           --> True
#            Is hours_per_week >= 50 ?
#            --> True
#             Predict {' <=50K': 1}
#            --> False
#             Is age >= 53 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 2}
#           --> False
#            Is hours_per_week >= 35 ?
#            --> True
#             Is native_country ==  India ?
#             --> True
#              Is hours_per_week >= 48 ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 1}
#             --> False
#              Is education ==  Prof-school ?
#              --> True
#               Is hours_per_week >= 50 ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 1}
#              --> False
#               Is age >= 46 ?
#               --> True
#                Predict {' >50K': 21}
#               --> False
#                Is fnlwgt >= 110562 ?
#                --> True
#                 Is fnlwgt >= 111363 ?
#                 --> True
#                  Is workclass ==  Federal-gov ?
#                  --> True
#                   Is education_num >= 14 ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Predict {' <=50K': 1}
#                  --> False
#                   Is fnlwgt >= 170983 ?
#                   --> True
#                    Is education_num >= 14 ?
#                    --> True
#                     Is hours_per_week >= 43 ?
#                     --> True
#                      Predict {' >50K': 2}
#                     --> False
#                      Predict {' <=50K': 1}
#                    --> False
#                     Is age >= 31 ?
#                     --> True
#                      Predict {' >50K': 16}
#                     --> False
#                      Is fnlwgt >= 208406 ?
#                      --> True
#                       Predict {' >50K': 2}
#                      --> False
#                       Predict {' <=50K': 1}
#                   --> False
#                    Is fnlwgt >= 158420 ?
#                    --> True
#                     Predict {' <=50K': 1}
#                    --> False
#                     Is hours_per_week >= 50 ?
#                     --> True
#                      Is age >= 35 ?
#                      --> True
#                       Is fnlwgt >= 119272 ?
#                       --> True
#                        Predict {' >50K': 3}
#                       --> False
#                        Is hours_per_week >= 70 ?
#                        --> True
#                         Predict {' >50K': 1}
#                        --> False
#                         Predict {' <=50K': 1}
#                      --> False
#                       Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 5}
#                 --> False
#                  Predict {' <=50K': 1}
#                --> False
#                 Predict {' >50K': 11}
#            --> False
#             Is hours_per_week >= 30 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 1}
#          --> False
#           Is age >= 37 ?
#           --> True
#            Predict {' >50K': 3}
#           --> False
#            Is education_num >= 14 ?
#            --> True
#             Predict {' <=50K': 2}
#            --> False
#             Is fnlwgt >= 40142 ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 1}
#      --> False
#       Predict {' <=50K': 4}
#     --> False
#      Is age >= 29 ?
#      --> True
#       Is fnlwgt >= 416745 ?
#       --> True
#        Predict {' <=50K': 7}
#       --> False
#        Is age >= 68 ?
#        --> True
#         Predict {' <=50K': 5}
#        --> False
#         Is native_country ==  United-States ?
#         --> True
#          Is education_num >= 16 ?
#          --> True
#           Predict {' >50K': 9}
#          --> False
#           Is fnlwgt >= 29841 ?
#           --> True
#            Is age >= 61 ?
#            --> True
#             Is hours_per_week >= 5 ?
#             --> True
#              Is hours_per_week >= 35 ?
#              --> True
#               Predict {' >50K': 9}
#              --> False
#               Is hours_per_week >= 30 ?
#               --> True
#                Is education_num >= 15 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 1}
#               --> False
#                Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 1}
#            --> False
#             Is workclass ==  Self-emp-not-inc ?
#             --> True
#              Is age >= 36 ?
#              --> True
#               Is fnlwgt >= 236852 ?
#               --> True
#                Is hours_per_week >= 45 ?
#                --> True
#                 Is fnlwgt >= 386397 ?
#                 --> True
#                  Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 3}
#                --> False
#                 Predict {' <=50K': 1}
#               --> False
#                Is hours_per_week >= 65 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Is education ==  Masters ?
#                 --> True
#                  Is hours_per_week >= 50 ?
#                  --> True
#                   Predict {' <=50K': 2}
#                  --> False
#                   Is occupation ==  Sales ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Predict {' <=50K': 1}
#                 --> False
#                  Predict {' <=50K': 8}
#              --> False
#               Predict {' >50K': 4}
#             --> False
#              Is fnlwgt >= 32668 ?
#              --> True
#               Is capital_loss >= 1740 ?
#               --> True
#                Predict {' <=50K': 2}
#               --> False
#                Is education ==  Masters ?
#                --> True
#                 Is occupation ==  Prof-specialty ?
#                 --> True
#                  Is workclass ==  Local-gov ?
#                  --> True
#                   Predict {' >50K': 3}
#                  --> False
#                   Is hours_per_week >= 40 ?
#                   --> True
#                    Is fnlwgt >= 192002 ?
#                    --> True
#                     Is fnlwgt >= 253354 ?
#                     --> True
#                      Predict {' <=50K': 2}
#                     --> False
#                      Is fnlwgt >= 202051 ?
#                      --> True
#                       Is fnlwgt >= 208405 ?
#                       --> True
#                        Predict {' >50K': 1}
#                       --> False
#                        Predict {' <=50K': 1}
#                      --> False
#                       Predict {' >50K': 1}
#                    --> False
#                     Predict {' <=50K': 8}
#                   --> False
#                    Is race ==  Black ?
#                    --> True
#                     Predict {' <=50K': 1}
#                    --> False
#                     Predict {' >50K': 2}
#                 --> False
#                  Is age >= 58 ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Predict {' >50K': 5}
#                --> False
#                 Is age >= 32 ?
#                 --> True
#                  Is age >= 33 ?
#                  --> True
#                   Is hours_per_week >= 52 ?
#                   --> True
#                    Is workclass ==  Local-gov ?
#                    --> True
#                     Predict {' <=50K': 3}
#                    --> False
#                     Is fnlwgt >= 84790 ?
#                     --> True
#                      Is hours_per_week >= 60 ?
#                      --> True
#                       Is fnlwgt >= 265099 ?
#                       --> True
#                        Predict {' <=50K': 2}
#                       --> False
#                        Is fnlwgt >= 210736 ?
#                        --> True
#                         Is occupation ==  Sales ?
#                         --> True
#                          Predict {' <=50K': 1}
#                         --> False
#                          Predict {' >50K': 2}
#                        --> False
#                         Predict {' >50K': 9}
#                      --> False
#                       Is fnlwgt >= 160402 ?
#                       --> True
#                        Predict {' >50K': 3}
#                       --> False
#                        Is fnlwgt >= 98929 ?
#                        --> True
#                         Predict {' <=50K': 5}
#                        --> False
#                         Predict {' >50K': 1}
#                     --> False
#                      Predict {' <=50K': 2}
#                   --> False
#                    Is fnlwgt >= 65390 ?
#                    --> True
#                     Is fnlwgt >= 76127 ?
#                     --> True
#                      Is age >= 47 ?
#                      --> True
#                       Is capital_gain >= 2885 ?
#                       --> True
#                        Predict {' <=50K': 1}
#                       --> False
#                        Is age >= 53 ?
#                        --> True
#                         Is occupation ==  Adm-clerical ?
#                         --> True
#                          Is hours_per_week >= 40 ?
#                          --> True
#                           Predict {' <=50K': 2}
#                          --> False
#                           Predict {' >50K': 1}
#                         --> False
#                          Is fnlwgt >= 106707 ?
#                          --> True
#                           Is education_num >= 13 ?
#                           --> True
#                            Is hours_per_week >= 50 ?
#                            --> True
#                             Is occupation ==  Sales ?
#                             --> True
#                              Predict {' >50K': 2}
#                             --> False
#                              Predict {' <=50K': 1}
#                            --> False
#                             Predict {' >50K': 9}
#                           --> False
#                            Is hours_per_week >= 25 ?
#                            --> True
#                             Predict {' <=50K': 1}
#                            --> False
#                             Predict {' >50K': 1}
#                          --> False
#                           Is occupation ==  Sales ?
#                           --> True
#                            Predict {' <=50K': 1}
#                           --> False
#                            Predict {' >50K': 1}
#                        --> False
#                         Predict {' >50K': 11}
#                      --> False
#                       Is education ==  Bachelors ?
#                       --> True
#                        Is hours_per_week >= 47 ?
#                        --> True
#                         Is fnlwgt >= 260960 ?
#                         --> True
#                          Predict {' <=50K': 1}
#                         --> False
#                          Predict {' >50K': 7}
#                        --> False
#                         Is occupation ==  Adm-clerical ?
#                         --> True
#                          Predict {' <=50K': 5}
#                         --> False
#                          Is sex ==  Male ?
#                          --> True
#                           Is fnlwgt >= 216214 ?
#                           --> True
#                            Is fnlwgt >= 353396 ?
#                            --> True
#                             Is fnlwgt >= 369468 ?
#                             --> True
#                              Predict {' >50K': 1}
#                             --> False
#                              Predict {' <=50K': 2}
#                            --> False
#                             Is hours_per_week >= 35 ?
#                             --> True
#                              Predict {' >50K': 7}
#                             --> False
#                              Predict {' <=50K': 1}
#                           --> False
#                            Is fnlwgt >= 160574 ?
#                            --> True
#                             Predict {' <=50K': 6}
#                            --> False
#                             Is age >= 41 ?
#                             --> True
#                              Is hours_per_week >= 40 ?
#                              --> True
#                               Predict {' >50K': 3}
#                              --> False
#                               Predict {' <=50K': 1}
#                             --> False
#                              Is age >= 39 ?
#                              --> True
#                               Predict {' <=50K': 3}
#                              --> False
#                               Is occupation ==  Sales ?
#                               --> True
#                                Predict {' >50K': 2}
#                               --> False
#                                Is capital_gain >= 3103 ?
#                                --> True
#                                 Predict {' >50K': 1}
#                                --> False
#                                 Predict {' <=50K': 2}
#                          --> False
#                           Predict {' >50K': 3}
#                       --> False
#                        Is occupation ==  Tech-support ?
#                        --> True
#                         Is fnlwgt >= 361888 ?
#                         --> True
#                          Predict {' >50K': 1}
#                         --> False
#                          Predict {' <=50K': 1}
#                        --> False
#                         Predict {' >50K': 11}
#                     --> False
#                      Predict {' <=50K': 2}
#                    --> False
#                     Predict {' >50K': 8}
#                  --> False
#                   Is education_num >= 15 ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Predict {' <=50K': 5}
#                 --> False
#                  Is capital_gain >= 2407 ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Is occupation ==  Sales ?
#                   --> True
#                    Is fnlwgt >= 200511 ?
#                    --> True
#                     Is hours_per_week >= 50 ?
#                     --> True
#                      Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 1}
#                    --> False
#                     Predict {' >50K': 2}
#                   --> False
#                    Predict {' >50K': 9}
#              --> False
#               Is hours_per_week >= 45 ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 4}
#           --> False
#            Predict {' >50K': 7}
#         --> False
#          Is education ==  Masters ?
#          --> True
#           Is sex ==  Male ?
#           --> True
#            Is native_country ==  China ?
#            --> True
#             Is hours_per_week >= 45 ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 1}
#            --> False
#             Predict {' >50K': 4}
#           --> False
#            Predict {' <=50K': 1}
#          --> False
#           Is native_country ==  Iran ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Is native_country ==  Taiwan ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Is workclass ==  Private ?
#             --> True
#              Is native_country ==  Italy ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 12}
#             --> False
#              Is fnlwgt >= 303446 ?
#              --> True
#               Predict {' <=50K': 2}
#              --> False
#               Is capital_gain >= 4064 ?
#               --> True
#                Predict {' <=50K': 1}
#               --> False
#                Predict {' >50K': 3}
#      --> False
#       Is fnlwgt >= 359155 ?
#       --> True
#        Is sex ==  Male ?
#        --> True
#         Is hours_per_week >= 99 ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Predict {' <=50K': 2}
#        --> False
#         Predict {' >50K': 2}
#       --> False
#        Is fnlwgt >= 172987 ?
#        --> True
#         Predict {' <=50K': 12}
#        --> False
#         Is education ==  Bachelors ?
#         --> True
#          Is occupation ==  Craft-repair ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Is fnlwgt >= 62438 ?
#           --> True
#            Predict {' >50K': 3}
#           --> False
#            Predict {' <=50K': 1}
#         --> False
#          Predict {' <=50K': 4}
#  --> False
#   Is capital_gain >= 5178 ?
#   --> True
#    Is age >= 62 ?
#    --> True
#     Is fnlwgt >= 118474 ?
#     --> True
#      Predict {' >50K': 3}
#     --> False
#      Predict {' <=50K': 3}
#    --> False
#     Predict {' >50K': 41}
#   --> False
#    Is education_num >= 9 ?
#    --> True
#     Is hours_per_week >= 36 ?
#     --> True
#      Is age >= 37 ?
#      --> True
#       Is capital_loss >= 1848 ?
#       --> True
#        Is capital_loss >= 2002 ?
#        --> True
#         Is capital_loss >= 2415 ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Predict {' <=50K': 6}
#        --> False
#         Is fnlwgt >= 96062 ?
#         --> True
#          Predict {' >50K': 14}
#         --> False
#          Is hours_per_week >= 50 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Predict {' <=50K': 1}
#       --> False
#        Is workclass ==  Self-emp-not-inc ?
#        --> True
#         Is race ==  White ?
#         --> True
#          Is age >= 58 ?
#          --> True
#           Predict {' <=50K': 12}
#          --> False
#           Is age >= 44 ?
#           --> True
#            Is fnlwgt >= 93208 ?
#            --> True
#             Is fnlwgt >= 209642 ?
#             --> True
#              Is fnlwgt >= 256866 ?
#              --> True
#               Is age >= 57 ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 2}
#              --> False
#               Is occupation ==  Transport-moving ?
#               --> True
#                Predict {' <=50K': 1}
#               --> False
#                Predict {' >50K': 5}
#             --> False
#              Is hours_per_week >= 99 ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Is age >= 45 ?
#               --> True
#                Predict {' <=50K': 10}
#               --> False
#                Is hours_per_week >= 66 ?
#                --> True
#                 Predict {' <=50K': 1}
#                --> False
#                 Predict {' >50K': 1}
#            --> False
#             Predict {' >50K': 3}
#           --> False
#            Predict {' <=50K': 11}
#         --> False
#          Is capital_gain >= 3137 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 4}
#        --> False
#         Is fnlwgt >= 242586 ?
#         --> True
#          Is hours_per_week >= 75 ?
#          --> True
#           Predict {' >50K': 2}
#          --> False
#           Is hours_per_week >= 50 ?
#           --> True
#            Is fnlwgt >= 563883 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 14}
#           --> False
#            Is occupation ==  Handlers-cleaners ?
#            --> True
#             Predict {' <=50K': 5}
#            --> False
#             Is fnlwgt >= 254230 ?
#             --> True
#              Is occupation ==  Prof-specialty ?
#              --> True
#               Is fnlwgt >= 266529 ?
#               --> True
#                Predict {' >50K': 4}
#               --> False
#                Predict {' <=50K': 1}
#              --> False
#               Is workclass ==  Private ?
#               --> True
#                Is age >= 55 ?
#                --> True
#                 Predict {' >50K': 3}
#                --> False
#                 Is fnlwgt >= 286750 ?
#                 --> True
#                  Is fnlwgt >= 310632 ?
#                  --> True
#                   Is age >= 48 ?
#                   --> True
#                    Predict {' <=50K': 4}
#                   --> False
#                    Is race ==  Black ?
#                    --> True
#                     Predict {' >50K': 3}
#                    --> False
#                     Is fnlwgt >= 373050 ?
#                     --> True
#                      Predict {' <=50K': 4}
#                     --> False
#                      Is occupation ==  Sales ?
#                      --> True
#                       Predict {' <=50K': 2}
#                      --> False
#                       Is capital_gain >= 5013 ?
#                       --> True
#                        Predict {' <=50K': 1}
#                       --> False
#                        Predict {' >50K': 5}
#                  --> False
#                   Predict {' <=50K': 5}
#                 --> False
#                  Is age >= 46 ?
#                  --> True
#                   Predict {' >50K': 4}
#                  --> False
#                   Is fnlwgt >= 283122 ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Predict {' <=50K': 2}
#               --> False
#                Is hours_per_week >= 40 ?
#                --> True
#                 Is capital_loss >= 1485 ?
#                 --> True
#                  Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 10}
#                --> False
#                 Predict {' >50K': 1}
#             --> False
#              Is occupation ==  Craft-repair ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 6}
#         --> False
#          Is fnlwgt >= 208358 ?
#          --> True
#           Is occupation ==  Transport-moving ?
#           --> True
#            Predict {' <=50K': 2}
#           --> False
#            Is workclass ==  Federal-gov ?
#            --> True
#             Predict {' <=50K': 1}
#            --> False
#             Is age >= 68 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Is hours_per_week >= 42 ?
#              --> True
#               Predict {' >50K': 8}
#              --> False
#               Is sex ==  Male ?
#               --> True
#                Is occupation ==  Prof-specialty ?
#                --> True
#                 Predict {' <=50K': 1}
#                --> False
#                 Is age >= 48 ?
#                 --> True
#                  Is education ==  Some-college ?
#                  --> True
#                   Is age >= 61 ?
#                   --> True
#                    Predict {' <=50K': 1}
#                   --> False
#                    Predict {' >50K': 2}
#                  --> False
#                   Predict {' >50K': 6}
#                 --> False
#                  Is occupation ==  Tech-support ?
#                  --> True
#                   Predict {' >50K': 2}
#                  --> False
#                   Is age >= 42 ?
#                   --> True
#                    Predict {' <=50K': 2}
#                   --> False
#                    Is occupation ==  Machine-op-inspct ?
#                    --> True
#                     Predict {' <=50K': 1}
#                    --> False
#                     Predict {' >50K': 2}
#               --> False
#                Predict {' >50K': 4}
#          --> False
#           Is hours_per_week >= 44 ?
#           --> True
#            Is education ==  Some-college ?
#            --> True
#             Is capital_loss >= 1485 ?
#             --> True
#              Predict {' <=50K': 2}
#             --> False
#              Is capital_gain >= 3137 ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Is fnlwgt >= 34368 ?
#               --> True
#                Is age >= 49 ?
#                --> True
#                 Is occupation ==  Craft-repair ?
#                 --> True
#                  Is hours_per_week >= 50 ?
#                  --> True
#                   Predict {' >50K': 1}
#                  --> False
#                   Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 13}
#                --> False
#                 Is fnlwgt >= 120939 ?
#                 --> True
#                  Is fnlwgt >= 125892 ?
#                  --> True
#                   Is fnlwgt >= 165186 ?
#                   --> True
#                    Is occupation ==  Sales ?
#                    --> True
#                     Predict {' <=50K': 1}
#                    --> False
#                     Is fnlwgt >= 176186 ?
#                     --> True
#                      Is hours_per_week >= 52 ?
#                      --> True
#                       Is hours_per_week >= 55 ?
#                       --> True
#                        Predict {' >50K': 1}
#                       --> False
#                        Predict {' <=50K': 1}
#                      --> False
#                       Predict {' >50K': 4}
#                     --> False
#                      Predict {' <=50K': 1}
#                   --> False
#                    Predict {' >50K': 3}
#                  --> False
#                   Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 4}
#               --> False
#                Predict {' <=50K': 1}
#            --> False
#             Is fnlwgt >= 169133 ?
#             --> True
#              Is hours_per_week >= 47 ?
#              --> True
#               Is occupation ==  Transport-moving ?
#               --> True
#                Predict {' >50K': 2}
#               --> False
#                Is hours_per_week >= 48 ?
#                --> True
#                 Is hours_per_week >= 99 ?
#                 --> True
#                  Predict {' >50K': 1}
#                 --> False
#                  Is age >= 47 ?
#                  --> True
#                   Is occupation ==  Adm-clerical ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Is occupation ==  Sales ?
#                    --> True
#                     Is fnlwgt >= 180195 ?
#                     --> True
#                      Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 1}
#                    --> False
#                     Predict {' <=50K': 3}
#                  --> False
#                   Predict {' <=50K': 6}
#                --> False
#                 Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 5}
#             --> False
#              Is fnlwgt >= 102102 ?
#              --> True
#               Is age >= 57 ?
#               --> True
#                Is occupation ==  Sales ?
#                --> True
#                 Is hours_per_week >= 50 ?
#                 --> True
#                  Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 1}
#                --> False
#                 Predict {' <=50K': 4}
#               --> False
#                Is age >= 39 ?
#                --> True
#                 Is occupation ==  Adm-clerical ?
#                 --> True
#                  Is hours_per_week >= 58 ?
#                  --> True
#                   Predict {' >50K': 1}
#                  --> False
#                   Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 19}
#                --> False
#                 Is hours_per_week >= 45 ?
#                 --> True
#                  Predict {' <=50K': 2}
#                 --> False
#                  Predict {' >50K': 1}
#              --> False
#               Is occupation ==  Handlers-cleaners ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Is age >= 53 ?
#                --> True
#                 Is hours_per_week >= 55 ?
#                 --> True
#                  Predict {' <=50K': 2}
#                 --> False
#                  Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 7}
#           --> False
#            Is education ==  Some-college ?
#            --> True
#             Is fnlwgt >= 169982 ?
#             --> True
#              Is age >= 44 ?
#              --> True
#               Is fnlwgt >= 188861 ?
#               --> True
#                Is capital_gain >= 4386 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 2}
#               --> False
#                Predict {' >50K': 4}
#              --> False
#               Is occupation ==  Protective-serv ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 5}
#             --> False
#              Is race ==  Asian-Pac-Islander ?
#              --> True
#               Is occupation ==  Exec-managerial ?
#               --> True
#                Predict {' <=50K': 1}
#               --> False
#                Predict {' >50K': 2}
#              --> False
#               Is fnlwgt >= 116632 ?
#               --> True
#                Is fnlwgt >= 133461 ?
#                --> True
#                 Predict {' <=50K': 8}
#                --> False
#                 Is occupation ==  Sales ?
#                 --> True
#                  Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 3}
#               --> False
#                Is hours_per_week >= 42 ?
#                --> True
#                 Is occupation ==  Transport-moving ?
#                 --> True
#                  Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 20}
#            --> False
#             Is fnlwgt >= 31339 ?
#             --> True
#              Is capital_gain >= 2885 ?
#              --> True
#               Predict {' <=50K': 5}
#              --> False
#               Is age >= 41 ?
#               --> True
#                Is fnlwgt >= 142182 ?
#                --> True
#                 Is fnlwgt >= 160586 ?
#                 --> True
#                  Is fnlwgt >= 194772 ?
#                  --> True
#                   Is fnlwgt >= 199378 ?
#                   --> True
#                    Is occupation ==  Craft-repair ?
#                    --> True
#                     Predict {' <=50K': 2}
#                    --> False
#                     Is occupation ==  Adm-clerical ?
#                     --> True
#                      Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 2}
#                   --> False
#                    Predict {' >50K': 3}
#                  --> False
#                   Is fnlwgt >= 176026 ?
#                   --> True
#                    Is age >= 51 ?
#                    --> True
#                     Is age >= 58 ?
#                     --> True
#                      Predict {' <=50K': 3}
#                     --> False
#                      Is fnlwgt >= 186338 ?
#                      --> True
#                       Predict {' >50K': 2}
#                      --> False
#                       Predict {' <=50K': 1}
#                    --> False
#                     Predict {' <=50K': 6}
#                   --> False
#                    Is fnlwgt >= 168232 ?
#                    --> True
#                     Is race ==  Black ?
#                     --> True
#                      Is occupation ==  Machine-op-inspct ?
#                      --> True
#                       Predict {' <=50K': 1}
#                      --> False
#                       Predict {' >50K': 1}
#                     --> False
#                      Predict {' >50K': 4}
#                    --> False
#                     Is occupation ==  Machine-op-inspct ?
#                     --> True
#                      Predict {' >50K': 1}
#                     --> False
#                      Is fnlwgt >= 166124 ?
#                      --> True
#                       Is fnlwgt >= 167651 ?
#                       --> True
#                        Predict {' <=50K': 3}
#                       --> False
#                        Is occupation ==  Exec-managerial ?
#                        --> True
#                         Predict {' <=50K': 1}
#                        --> False
#                         Predict {' >50K': 2}
#                      --> False
#                       Predict {' <=50K': 5}
#                 --> False
#                  Is occupation ==  Machine-op-inspct ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Predict {' >50K': 7}
#                --> False
#                 Is age >= 65 ?
#                 --> True
#                  Predict {' >50K': 2}
#                 --> False
#                  Is occupation ==  Sales ?
#                  --> True
#                   Is fnlwgt >= 138634 ?
#                   --> True
#                    Predict {' <=50K': 1}
#                   --> False
#                    Predict {' >50K': 3}
#                  --> False
#                   Is fnlwgt >= 53707 ?
#                   --> True
#                    Is fnlwgt >= 54851 ?
#                    --> True
#                     Is occupation ==  Exec-managerial ?
#                     --> True
#                      Predict {' >50K': 1}
#                     --> False
#                      Is occupation ==  Transport-moving ?
#                      --> True
#                       Is age >= 46 ?
#                       --> True
#                        Is fnlwgt >= 93690 ?
#                        --> True
#                         Is fnlwgt >= 114060 ?
#                         --> True
#                          Predict {' <=50K': 1}
#                         --> False
#                          Predict {' >50K': 1}
#                        --> False
#                         Predict {' <=50K': 1}
#                       --> False
#                        Predict {' >50K': 1}
#                      --> False
#                       Is fnlwgt >= 121264 ?
#                       --> True
#                        Is fnlwgt >= 126010 ?
#                        --> True
#                         Predict {' <=50K': 6}
#                        --> False
#                         Is occupation ==  Prof-specialty ?
#                         --> True
#                          Predict {' >50K': 2}
#                         --> False
#                          Is sex ==  Male ?
#                          --> True
#                           Predict {' <=50K': 2}
#                          --> False
#                           Predict {' >50K': 1}
#                       --> False
#                        Is age >= 58 ?
#                        --> True
#                         Is age >= 60 ?
#                         --> True
#                          Predict {' <=50K': 4}
#                         --> False
#                          Predict {' >50K': 1}
#                        --> False
#                         Predict {' <=50K': 10}
#                    --> False
#                     Predict {' >50K': 2}
#                   --> False
#                    Predict {' <=50K': 6}
#               --> False
#                Is education_num >= 11 ?
#                --> True
#                 Predict {' >50K': 4}
#                --> False
#                 Is fnlwgt >= 105813 ?
#                 --> True
#                  Is occupation ==  Exec-managerial ?
#                  --> True
#                   Predict {' >50K': 2}
#                  --> False
#                   Is occupation ==  Transport-moving ?
#                   --> True
#                    Is fnlwgt >= 117683 ?
#                    --> True
#                     Is fnlwgt >= 164663 ?
#                     --> True
#                      Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 1}
#                    --> False
#                     Predict {' <=50K': 1}
#                   --> False
#                    Predict {' <=50K': 4}
#                 --> False
#                  Predict {' >50K': 3}
#             --> False
#              Predict {' >50K': 3}
#      --> False
#       Is occupation ==  Exec-managerial ?
#       --> True
#        Is fnlwgt >= 78530 ?
#        --> True
#         Is age >= 31 ?
#         --> True
#          Is capital_loss >= 1672 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Is fnlwgt >= 364657 ?
#           --> True
#            Predict {' <=50K': 1}
#           --> False
#            Is fnlwgt >= 284616 ?
#            --> True
#             Is hours_per_week >= 50 ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 1}
#            --> False
#             Predict {' >50K': 9}
#         --> False
#          Is native_country ==  Canada ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Predict {' <=50K': 3}
#        --> False
#         Predict {' <=50K': 3}
#       --> False
#        Is hours_per_week >= 40 ?
#        --> True
#         Is fnlwgt >= 33308 ?
#         --> True
#          Is occupation ==  Sales ?
#          --> True
#           Is age >= 33 ?
#           --> True
#            Is hours_per_week >= 66 ?
#            --> True
#             Predict {' <=50K': 1}
#            --> False
#             Predict {' >50K': 7}
#           --> False
#            Is age >= 27 ?
#            --> True
#             Is education_num >= 11 ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 10}
#            --> False
#             Is hours_per_week >= 44 ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 1}
#          --> False
#           Is fnlwgt >= 167350 ?
#           --> True
#            Is fnlwgt >= 174391 ?
#            --> True
#             Is workclass ==  Federal-gov ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Is hours_per_week >= 42 ?
#              --> True
#               Is age >= 35 ?
#               --> True
#                Predict {' <=50K': 6}
#               --> False
#                Is fnlwgt >= 490332 ?
#                --> True
#                 Predict {' >50K': 2}
#                --> False
#                 Is fnlwgt >= 358636 ?
#                 --> True
#                  Predict {' <=50K': 3}
#                 --> False
#                  Is fnlwgt >= 303954 ?
#                  --> True
#                   Predict {' >50K': 2}
#                  --> False
#                   Is education_num >= 10 ?
#                   --> True
#                    Predict {' <=50K': 4}
#                   --> False
#                    Is occupation ==  Handlers-cleaners ?
#                    --> True
#                     Predict {' <=50K': 2}
#                    --> False
#                     Is occupation ==  Transport-moving ?
#                     --> True
#                      Is hours_per_week >= 45 ?
#                      --> True
#                       Is hours_per_week >= 50 ?
#                       --> True
#                        Predict {' <=50K': 1}
#                       --> False
#                        Predict {' >50K': 1}
#                      --> False
#                       Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 4}
#              --> False
#               Is occupation ==  Tech-support ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Is age >= 30 ?
#                --> True
#                 Is native_country ==  Mexico ?
#                 --> True
#                  Is occupation ==  Adm-clerical ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Predict {' >50K': 1}
#                 --> False
#                  Is occupation ==  Handlers-cleaners ?
#                  --> True
#                   Is education_num >= 10 ?
#                   --> True
#                    Predict {' <=50K': 1}
#                   --> False
#                    Predict {' >50K': 1}
#                  --> False
#                   Is fnlwgt >= 326104 ?
#                   --> True
#                    Is fnlwgt >= 363032 ?
#                    --> True
#                     Predict {' <=50K': 4}
#                    --> False
#                     Predict {' >50K': 2}
#                   --> False
#                    Is fnlwgt >= 194141 ?
#                    --> True
#                     Is sex ==  Male ?
#                     --> True
#                      Predict {' <=50K': 17}
#                     --> False
#                      Is occupation ==  Craft-repair ?
#                      --> True
#                       Is fnlwgt >= 267404 ?
#                       --> True
#                        Predict {' <=50K': 1}
#                       --> False
#                        Predict {' >50K': 1}
#                      --> False
#                       Predict {' <=50K': 2}
#                    --> False
#                     Is race ==  Black ?
#                     --> True
#                      Predict {' >50K': 1}
#                     --> False
#                      Predict {' <=50K': 3}
#                --> False
#                 Predict {' <=50K': 19}
#            --> False
#             Predict {' >50K': 3}
#           --> False
#            Is occupation ==  Protective-serv ?
#            --> True
#             Is fnlwgt >= 166606 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 2}
#            --> False
#             Is hours_per_week >= 70 ?
#             --> True
#              Is hours_per_week >= 72 ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 1}
#             --> False
#              Is workclass ==  Local-gov ?
#              --> True
#               Is occupation ==  Craft-repair ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 3}
#              --> False
#               Is fnlwgt >= 160449 ?
#               --> True
#                Is fnlwgt >= 160728 ?
#                --> True
#                 Predict {' <=50K': 5}
#                --> False
#                 Predict {' >50K': 1}
#               --> False
#                Is occupation ==  Craft-repair ?
#                --> True
#                 Is fnlwgt >= 106742 ?
#                 --> True
#                  Predict {' <=50K': 11}
#                 --> False
#                  Is fnlwgt >= 94235 ?
#                  --> True
#                   Predict {' >50K': 1}
#                  --> False
#                   Predict {' <=50K': 9}
#                --> False
#                 Predict {' <=50K': 43}
#         --> False
#          Predict {' >50K': 3}
#        --> False
#         Predict {' >50K': 3}
#     --> False
#      Is occupation ==  Tech-support ?
#      --> True
#       Is hours_per_week >= 32 ?
#       --> True
#        Predict {' <=50K': 1}
#       --> False
#        Predict {' >50K': 2}
#      --> False
#       Is capital_loss >= 2415 ?
#       --> True
#        Predict {' >50K': 1}
#       --> False
#        Is fnlwgt >= 195733 ?
#        --> True
#         Is fnlwgt >= 203580 ?
#         --> True
#          Is hours_per_week >= 15 ?
#          --> True
#           Is occupation ==  Adm-clerical ?
#           --> True
#            Is sex ==  Male ?
#            --> True
#             Predict {' <=50K': 3}
#            --> False
#             Predict {' >50K': 1}
#           --> False
#            Predict {' <=50K': 21}
#          --> False
#           Predict {' >50K': 1}
#         --> False
#          Is hours_per_week >= 30 ?
#          --> True
#           Predict {' >50K': 3}
#          --> False
#           Predict {' <=50K': 2}
#        --> False
#         Is education_num >= 11 ?
#         --> True
#          Is fnlwgt >= 172425 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Predict {' <=50K': 2}
#         --> False
#          Is occupation ==  Transport-moving ?
#          --> True
#           Is education_num >= 10 ?
#           --> True
#            Is fnlwgt >= 121912 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 1}
#           --> False
#            Predict {' <=50K': 3}
#          --> False
#           Predict {' <=50K': 45}
#    --> False
#     Is fnlwgt >= 26145 ?
#     --> True
#      Is native_country ==  Greece ?
#      --> True
#       Predict {' >50K': 1}
#      --> False
#       Is workclass ==  Self-emp-inc ?
#       --> True
#        Is occupation ==  Craft-repair ?
#        --> True
#         Predict {' >50K': 1}
#        --> False
#         Is occupation ==  Machine-op-inspct ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Predict {' <=50K': 4}
#       --> False
#        Is race ==  Black ?
#        --> True
#         Is fnlwgt >= 245305 ?
#         --> True
#          Is hours_per_week >= 40 ?
#          --> True
#           Predict {' >50K': 3}
#          --> False
#           Predict {' <=50K': 3}
#         --> False
#          Predict {' <=50K': 6}
#        --> False
#         Is hours_per_week >= 55 ?
#         --> True
#          Is native_country ==  Italy ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is workclass ==  Private ?
#           --> True
#            Is hours_per_week >= 70 ?
#            --> True
#             Predict {' <=50K': 3}
#            --> False
#             Is age >= 55 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 2}
#           --> False
#            Predict {' <=50K': 7}
#         --> False
#          Is workclass ==  State-gov ?
#          --> True
#           Is occupation ==  Adm-clerical ?
#           --> True
#            Predict {' <=50K': 1}
#           --> False
#            Predict {' >50K': 1}
#          --> False
#           Is education ==  1st-4th ?
#           --> True
#            Is fnlwgt >= 324420 ?
#            --> True
#             Predict {' <=50K': 4}
#            --> False
#             Predict {' >50K': 1}
#           --> False
#            Is native_country ==  Mexico ?
#            --> True
#             Is education ==  7th-8th ?
#             --> True
#              Is fnlwgt >= 286370 ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 3}
#             --> False
#              Predict {' <=50K': 15}
#            --> False
#             Predict {' <=50K': 111}
#     --> False
#      Predict {' >50K': 1}
# --> False
#  Is capital_gain >= 8614 ?
#  --> True
#   Is hours_per_week >= 40 ?
#   --> True
#    Predict {' >50K': 18}
#   --> False
#    Predict {' <=50K': 1}
#  --> False
#   Is education_num >= 13 ?
#   --> True
#    Is age >= 32 ?
#    --> True
#     Is capital_loss >= 2392 ?
#     --> True
#      Predict {' >50K': 3}
#     --> False
#      Is hours_per_week >= 45 ?
#      --> True
#       Is fnlwgt >= 386773 ?
#       --> True
#        Predict {' >50K': 4}
#       --> False
#        Is relationship ==  Own-child ?
#        --> True
#         Predict {' >50K': 2}
#        --> False
#         Is workclass ==  Federal-gov ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Is age >= 51 ?
#          --> True
#           Is capital_loss >= 1564 ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Predict {' <=50K': 10}
#          --> False
#           Is age >= 50 ?
#           --> True
#            Predict {' >50K': 2}
#           --> False
#            Is capital_gain >= 4934 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Is fnlwgt >= 34028 ?
#             --> True
#              Is occupation ==  Exec-managerial ?
#              --> True
#               Is fnlwgt >= 38563 ?
#               --> True
#                Is race ==  White ?
#                --> True
#                 Is hours_per_week >= 75 ?
#                 --> True
#                  Predict {' <=50K': 1}
#                 --> False
#                  Is age >= 45 ?
#                  --> True
#                   Predict {' >50K': 3}
#                  --> False
#                   Is marital_status ==  Separated ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Is relationship ==  Unmarried ?
#                    --> True
#                     Is capital_loss >= 213 ?
#                     --> True
#                      Predict {' <=50K': 1}
#                     --> False
#                      Predict {' >50K': 2}
#                    --> False
#                     Is hours_per_week >= 50 ?
#                     --> True
#                      Predict {' <=50K': 3}
#                     --> False
#                      Is capital_loss >= 1741 ?
#                      --> True
#                       Predict {' <=50K': 1}
#                      --> False
#                       Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 2}
#               --> False
#                Predict {' <=50K': 3}
#              --> False
#               Is fnlwgt >= 228456 ?
#               --> True
#                Predict {' <=50K': 9}
#               --> False
#                Is fnlwgt >= 180572 ?
#                --> True
#                 Is fnlwgt >= 187119 ?
#                 --> True
#                  Is occupation ==  Prof-specialty ?
#                  --> True
#                   Is sex ==  Female ?
#                   --> True
#                    Is marital_status ==  Never-married ?
#                    --> True
#                     Predict {' <=50K': 1}
#                    --> False
#                     Predict {' >50K': 1}
#                   --> False
#                    Predict {' >50K': 1}
#                  --> False
#                   Predict {' <=50K': 3}
#                 --> False
#                  Predict {' >50K': 2}
#                --> False
#                 Is occupation ==  Sales ?
#                 --> True
#                  Is fnlwgt >= 138370 ?
#                  --> True
#                   Predict {' <=50K': 3}
#                  --> False
#                   Is sex ==  Male ?
#                   --> True
#                    Predict {' >50K': 2}
#                   --> False
#                    Predict {' <=50K': 1}
#                 --> False
#                  Predict {' <=50K': 10}
#             --> False
#              Predict {' >50K': 1}
#      --> False
#       Is capital_gain >= 4787 ?
#       --> True
#        Predict {' >50K': 2}
#       --> False
#        Is education ==  Prof-school ?
#        --> True
#         Is sex ==  Male ?
#         --> True
#          Predict {' >50K': 2}
#         --> False
#          Predict {' <=50K': 2}
#        --> False
#         Is fnlwgt >= 90758 ?
#         --> True
#          Is fnlwgt >= 102628 ?
#          --> True
#           Is fnlwgt >= 177937 ?
#           --> True
#            Is fnlwgt >= 183168 ?
#            --> True
#             Is workclass ==  Self-emp-not-inc ?
#             --> True
#              Is marital_status ==  Never-married ?
#              --> True
#               Predict {' <=50K': 2}
#              --> False
#               Predict {' >50K': 2}
#             --> False
#              Is occupation ==  Exec-managerial ?
#              --> True
#               Is fnlwgt >= 221532 ?
#               --> True
#                Predict {' >50K': 2}
#               --> False
#                Predict {' <=50K': 3}
#              --> False
#               Is fnlwgt >= 340428 ?
#               --> True
#                Is fnlwgt >= 365996 ?
#                --> True
#                 Predict {' <=50K': 7}
#                --> False
#                 Predict {' >50K': 2}
#               --> False
#                Predict {' <=50K': 24}
#            --> False
#             Is hours_per_week >= 35 ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 1}
#           --> False
#            Is age >= 46 ?
#            --> True
#             Is age >= 49 ?
#             --> True
#              Predict {' <=50K': 8}
#             --> False
#              Is fnlwgt >= 125421 ?
#              --> True
#               Predict {' >50K': 2}
#              --> False
#               Predict {' <=50K': 3}
#            --> False
#             Predict {' <=50K': 23}
#          --> False
#           Is occupation ==  Sales ?
#           --> True
#            Predict {' <=50K': 2}
#           --> False
#            Predict {' >50K': 4}
#         --> False
#          Predict {' <=50K': 15}
#    --> False
#     Is education ==  Prof-school ?
#     --> True
#      Is hours_per_week >= 70 ?
#      --> True
#       Predict {' <=50K': 2}
#      --> False
#       Predict {' >50K': 3}
#     --> False
#      Is fnlwgt >= 355259 ?
#      --> True
#       Is hours_per_week >= 50 ?
#       --> True
#        Predict {' >50K': 2}
#       --> False
#        Is fnlwgt >= 363425 ?
#        --> True
#         Predict {' <=50K': 9}
#        --> False
#         Predict {' >50K': 1}
#      --> False
#       Is workclass ==  Self-emp-not-inc ?
#       --> True
#        Is race ==  Black ?
#        --> True
#         Predict {' >50K': 1}
#        --> False
#         Predict {' <=50K': 6}
#       --> False
#        Is fnlwgt >= 41107 ?
#        --> True
#         Predict {' <=50K': 121}
#        --> False
#         Is occupation ==  Exec-managerial ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Predict {' <=50K': 9}
#   --> False
#    Is hours_per_week >= 42 ?
#    --> True
#     Is age >= 52 ?
#     --> True
#      Is sex ==  Male ?
#      --> True
#       Is fnlwgt >= 123273 ?
#       --> True
#        Is age >= 58 ?
#        --> True
#         Predict {' <=50K': 5}
#        --> False
#         Predict {' >50K': 2}
#       --> False
#        Predict {' >50K': 4}
#      --> False
#       Predict {' <=50K': 10}
#     --> False
#      Is native_country ==  Iran ?
#      --> True
#       Predict {' >50K': 1}
#      --> False
#       Is education ==  12th ?
#       --> True
#        Predict {' >50K': 1}
#       --> False
#        Is occupation ==  Prof-specialty ?
#        --> True
#         Is fnlwgt >= 467108 ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Is workclass ==  State-gov ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is education_num >= 10 ?
#           --> True
#            Predict {' <=50K': 10}
#           --> False
#            Is hours_per_week >= 75 ?
#            --> True
#             Predict {' <=50K': 1}
#            --> False
#             Predict {' >50K': 1}
#        --> False
#         Is age >= 43 ?
#         --> True
#          Is fnlwgt >= 363418 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is relationship ==  Unmarried ?
#           --> True
#            Is education ==  Some-college ?
#            --> True
#             Is occupation ==  Exec-managerial ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 2}
#            --> False
#             Predict {' <=50K': 6}
#           --> False
#            Predict {' <=50K': 17}
#         --> False
#          Is education ==  11th ?
#          --> True
#           Is marital_status ==  Divorced ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Predict {' <=50K': 4}
#          --> False
#           Is workclass ==  Self-emp-not-inc ?
#           --> True
#            Is occupation ==  Craft-repair ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 9}
#           --> False
#            Is occupation ==  Exec-managerial ?
#            --> True
#             Is fnlwgt >= 164866 ?
#             --> True
#              Predict {' <=50K': 13}
#             --> False
#              Is fnlwgt >= 161708 ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 3}
#            --> False
#             Is occupation ==  Sales ?
#             --> True
#              Is education_num >= 10 ?
#              --> True
#               Predict {' <=50K': 18}
#              --> False
#               Is age >= 28 ?
#               --> True
#                Predict {' <=50K': 7}
#               --> False
#                Is age >= 27 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 4}
#             --> False
#              Predict {' <=50K': 114}
#    --> False
#     Is fnlwgt >= 23778 ?
#     --> True
#      Is native_country ==  India ?
#      --> True
#       Is occupation ==  Adm-clerical ?
#       --> True
#        Predict {' <=50K': 1}
#       --> False
#        Predict {' >50K': 1}
#      --> False
#       Is native_country ==  Philippines ?
#       --> True
#        Is relationship ==  Unmarried ?
#        --> True
#         Predict {' >50K': 1}
#        --> False
#         Predict {' <=50K': 4}
#       --> False
#        Is occupation ==  Tech-support ?
#        --> True
#         Is marital_status ==  Separated ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Is sex ==  Male ?
#          --> True
#           Is education ==  Some-college ?
#           --> True
#            Is capital_gain >= 2174 ?
#            --> True
#             Predict {' <=50K': 1}
#            --> False
#             Predict {' >50K': 1}
#           --> False
#            Predict {' <=50K': 4}
#          --> False
#           Predict {' <=50K': 16}
#        --> False
#         Is marital_status ==  Married-spouse-absent ?
#         --> True
#          Is fnlwgt >= 30602 ?
#          --> True
#           Is hours_per_week >= 25 ?
#           --> True
#            Predict {' <=50K': 21}
#           --> False
#            Is sex ==  Male ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 2}
#          --> False
#           Predict {' >50K': 1}
#         --> False
#          Is education ==  Assoc-voc ?
#          --> True
#           Is capital_loss >= 1564 ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Is workclass ==  Federal-gov ?
#            --> True
#             Is race ==  Black ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 1}
#            --> False
#             Predict {' <=50K': 42}
#          --> False
#           Is occupation ==  Protective-serv ?
#           --> True
#            Is fnlwgt >= 318280 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 18}
#           --> False
#            Is age >= 30 ?
#            --> True
#             Is education ==  HS-grad ?
#             --> True
#              Predict {' <=50K': 250}
#             --> False
#              Is sex ==  Female ?
#              --> True
#               Is education ==  11th ?
#               --> True
#                Is occupation ==  Exec-managerial ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 12}
#               --> False
#                Predict {' <=50K': 129}
#              --> False
#               Is occupation ==  Prof-specialty ?
#               --> True
#                Is education_num >= 10 ?
#                --> True
#                 Is age >= 52 ?
#                 --> True
#                  Predict {' >50K': 2}
#                 --> False
#                  Predict {' <=50K': 3}
#                --> False
#                 Predict {' <=50K': 10}
#               --> False
#                Is age >= 31 ?
#                --> True
#                 Is occupation ==  Transport-moving ?
#                 --> True
#                  Is education ==  10th ?
#                  --> True
#                   Is relationship ==  Unmarried ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Predict {' <=50K': 1}
#                  --> False
#                   Predict {' <=50K': 7}
#                 --> False
#                  Predict {' <=50K': 63}
#                --> False
#                 Is occupation ==  Craft-repair ?
#                 --> True
#                  Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 5}
#            --> False
#             Predict {' <=50K': 505}
#     --> False
#      Is fnlwgt >= 23074 ?
#      --> True
#       Predict {' >50K': 2}
#      --> False
#       Predict {' <=50K': 2}

# %%
# 2. Best Height Possible over 20 possible Depth and max_depth Input taken from the user

# %%
def return_best_depth(df):
    
    best_tree = None
    best_depth = 0.0
    sum_of_accuracy = 0.0
    best_accuracy = 0.0
    
    plot_x = []
    plot_y = []
    infinity = 100; ### edit for more than hundread if you want
    
    for i in range(20):
        
        """
        Keep taking input unless maximum accuracy achived
        """
        max_depth = int(input("Give a max_depth:"))
#         max_depth = -1;
        
#         train, test = split_data_random(df)
        train, test = split_data_random(df[:4000]) # uncomment to use for lesser data as 40K of instances will take huge time 
        training_data = newList_from_df(train)
        testing_data = newList_from_df(test)
        
        if max_depth == -1:
            max_depth = infinity
            
        my_tree_ = build_tree_max_depth(training_data,1, max_depth)
        
        new_accuracy = predict_accuracy(my_tree_,testing_data)
                
        sum_of_accuracy += new_accuracy
        
        plot_x.append(tree_depth(my_tree_))
        plot_y.append(new_accuracy)
        
        if new_accuracy > best_accuracy:
            best_accuracy = new_accuracy
            best_tree = my_tree_
            
        
    return tree_depth(best_tree), plot_x,plot_y

# %%
best_depth, depth_x, acc_y = return_best_depth(df)
print("Best Depth Obtained:"+ str(best_depth))
plot_graph(depth_x, acc_y)
# Out:
# Give a max_depth:1
# Give a max_depth:2
# Give a max_depth:3
# Give a max_depth:4
# Give a max_depth:6
# Give a max_depth:7
# Give a max_depth:8
# Give a max_depth:10
# Give a max_depth:12
# Give a max_depth:15
# Give a max_depth:16
# Give a max_depth:17
# Give a max_depth:18
# Give a max_depth:-1
# Give a max_depth:19
# Give a max_depth:21
# Give a max_depth:20
# Give a max_depth:23
# Give a max_depth:25
# Give a max_depth:27
# Best Depth Obtained:27

# %%
def pruning_result(tree,training_data,validation_data):
    
    if len(training_data) == 0 or len(validation_data)==0:
        return tree
    acc_dT = predict_accuracy(tree, validation_data)
    new_Leaf = Leaf(training_data)
    acc_leaf = predict_accuracy(new_Leaf,validation_data)
    
    if acc_leaf >= acc_dT :
        return new_Leaf
    else:
        return tree

# %%
def post_pruning(tree,training_data,validation_data):
    
    true_branch, false_branch = tree.true_branch, tree.false_branch
    
    if isinstance(true_branch,Leaf) and isinstance(false_branch,Leaf):
        return pruning_result(tree, training_data, validation_data)
    
    else:
        
        train_true, train_false = partition(training_data, tree.question)
        valid_true, valid_false = partition(validation_data, tree.question)
        
        if not isinstance(true_branch, Leaf):
            
            tree.true_branch = post_pruning(true_branch, train_true, valid_true)
        
        if not isinstance(false_branch, Leaf):
            
            tree.false_branch = post_pruning(false_branch, train_false, valid_false)

        return pruning_result(tree, training_data, validation_data)

# %%
# Pruning Operation to be performed by creating a tree of best_depth obtained from part 2

# %%
trainP,valP= split_data_random(df[4000:8000])
trainingP_data, validationP_data = newList_from_df(trainP), newList_from_df(valP)

# %%
tree_to_be_prunned = build_tree_max_depth(trainingP_data,1,best_depth)

# %%
print("accuracy_on_training_data_before_prunning: "+ str(predict_accuracy(tree_to_be_prunned,trainingP_data)))
tree_prunned = post_pruning(tree_to_be_Prunned, trainingP_data, validationP_data)
print("accuracy_on_training_data_after_prunning: "+ str(predict_accuracy(tree_prunned,trainingP_data)))
# Out:
# accuracy_on_training_data_before_prunning: 95.15625
# accuracy_on_training_data_after_prunning: 91.15625

# %%
print_tree(tree_pruned) ## printing prunned tree
# Out:
# Is marital_status ==  Married-civ-spouse ?
# --> True
#  Is education_num >= 13 ?
#  --> True
#   Is age >= 34 ?
#   --> True
#    Is age >= 64 ?
#    --> True
#     Is fnlwgt >= 143716 ?
#     --> True
#      Is hours_per_week >= 60 ?
#      --> True
#       Is native_country ==  China ?
#       --> True
#        Predict {' <=50K': 1}
#       --> False
#        Predict {' >50K': 3}
#      --> False
#       Is fnlwgt >= 330144 ?
#       --> True
#        Predict {' >50K': 1}
#       --> False
#        Predict {' <=50K': 12}
#     --> False
#      Predict {' >50K': 4}
#    --> False
#     Is occupation ==  Transport-moving ?
#     --> True
#      Predict {' <=50K': 4}
#     --> False
#      Is education_num >= 14 ?
#      --> True
#       Is native_country ==  Canada ?
#       --> True
#        Predict {' <=50K': 1}
#       --> False
#        Is hours_per_week >= 30 ?
#        --> True
#         Is age >= 59 ?
#         --> True
#          Is fnlwgt >= 171355 ?
#          --> True
#           Predict {' >50K': 2}
#          --> False
#           Predict {' <=50K': 2}
#         --> False
#          Is native_country ==  India ?
#          --> True
#           Is race ==  White ?
#           --> True
#            Predict {' <=50K': 1}
#           --> False
#            Predict {' >50K': 2}
#          --> False
#           Is fnlwgt >= 333305 ?
#           --> True
#            Is hours_per_week >= 36 ?
#            --> True
#             Is occupation ==  Adm-clerical ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 10}
#            --> False
#             Predict {' <=50K': 1}
#           --> False
#            Is fnlwgt >= 34104 ?
#            --> True
#             Is hours_per_week >= 60 ?
#             --> True
#              Is education_num >= 15 ?
#              --> True
#               Predict {' >50K': 16}
#              --> False
#               Is fnlwgt >= 206066 ?
#               --> True
#                Is hours_per_week >= 70 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 2}
#               --> False
#                Predict {' >50K': 4}
#             --> False
#              Predict {' >50K': 72}
#            --> False
#             Is fnlwgt >= 33863 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 3}
#        --> False
#         Predict {' <=50K': 1}
#      --> False
#       Is native_country ==  United-States ?
#       --> True
#        Is fnlwgt >= 102096 ?
#        --> True
#         Is capital_gain >= 7298 ?
#         --> True
#          Predict {' >50K': 20}
#         --> False
#          Is hours_per_week >= 20 ?
#          --> True
#           Is race ==  Black ?
#           --> True
#            Predict {' <=50K': 2}
#           --> False
#            Is workclass ==  State-gov ?
#            --> True
#             Predict {' >50K': 1, ' <=50K': 2}
#            --> False
#             Is capital_gain >= 4064 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Is race ==  Amer-Indian-Eskimo ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Is age >= 56 ?
#               --> True
#                Is hours_per_week >= 58 ?
#                --> True
#                 Predict {' <=50K': 2}
#                --> False
#                 Is occupation ==  Sales ?
#                 --> True
#                  Is hours_per_week >= 35 ?
#                  --> True
#                   Predict {' <=50K': 2}
#                  --> False
#                   Predict {' >50K': 1}
#                 --> False
#                  Predict {' >50K': 5}
#               --> False
#                Is age >= 40 ?
#                --> True
#                 Is occupation ==  Tech-support ?
#                 --> True
#                  Is hours_per_week >= 40 ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Predict {' >50K': 1}
#                 --> False
#                  Is occupation ==  Adm-clerical ?
#                  --> True
#                   Predict {' <=50K': 1, ' >50K': 2}
#                  --> False
#                   Is occupation ==  Craft-repair ?
#                   --> True
#                    Is fnlwgt >= 187322 ?
#                    --> True
#                     Predict {' >50K': 3}
#                    --> False
#                     Predict {' <=50K': 1}
#                   --> False
#                    Predict {' >50K': 41}
#                --> False
#                 Is occupation ==  Exec-managerial ?
#                 --> True
#                  Is age >= 38 ?
#                  --> True
#                   Predict {' <=50K': 3}
#                  --> False
#                   Is hours_per_week >= 50 ?
#                   --> True
#                    Predict {' >50K': 3}
#                   --> False
#                    Is capital_loss >= 1887 ?
#                    --> True
#                     Predict {' >50K': 1}
#                    --> False
#                     Predict {' <=50K': 2}
#                 --> False
#                  Is workclass ==  Self-emp-inc ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Is workclass ==  Local-gov ?
#                   --> True
#                    Is age >= 37 ?
#                    --> True
#                     Predict {' >50K': 3}
#                    --> False
#                     Predict {' <=50K': 1}
#                   --> False
#                    Predict {' >50K': 19}
#          --> False
#           Predict {' <=50K': 2}
#        --> False
#         Predict {' >50K': 13, ' <=50K': 11}
#       --> False
#        Is fnlwgt >= 137547 ?
#        --> True
#         Is native_country ==  Japan ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Is native_country ==  Poland ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is native_country ==  Canada ?
#           --> True
#            Is hours_per_week >= 45 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 1}
#           --> False
#            Predict {' <=50K': 9}
#        --> False
#         Predict {' >50K': 3}
#   --> False
#    Is capital_loss >= 1848 ?
#    --> True
#     Is native_country ==  Iran ?
#     --> True
#      Predict {' <=50K': 1}
#     --> False
#      Predict {' >50K': 9}
#    --> False
#     Is capital_gain >= 7298 ?
#     --> True
#      Predict {' >50K': 4}
#     --> False
#      Is fnlwgt >= 109282 ?
#      --> True
#       Is fnlwgt >= 150570 ?
#       --> True
#        Is hours_per_week >= 42 ?
#        --> True
#         Is age >= 29 ?
#         --> True
#          Predict {' >50K': 3, ' <=50K': 6}
#         --> False
#          Is capital_gain >= 4064 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 7}
#        --> False
#         Is occupation ==  Exec-managerial ?
#         --> True
#          Is native_country ==  Dominican-Republic ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Is fnlwgt >= 340940 ?
#           --> True
#            Predict {' <=50K': 1}
#           --> False
#            Predict {' >50K': 3}
#         --> False
#          Is fnlwgt >= 473133 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is occupation ==  Sales ?
#           --> True
#            Is fnlwgt >= 190143 ?
#            --> True
#             Is fnlwgt >= 280344 ?
#             --> True
#              Is native_country ==  India ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 3}
#            --> False
#             Is fnlwgt >= 155781 ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 1}
#           --> False
#            Predict {' <=50K': 18}
#       --> False
#        Is occupation ==  Craft-repair ?
#        --> True
#         Predict {' <=50K': 1}
#        --> False
#         Is workclass ==  Local-gov ?
#         --> True
#          Predict {' <=50K': 1}
#         --> False
#          Is age >= 29 ?
#          --> True
#           Predict {' >50K': 10}
#          --> False
#           Is hours_per_week >= 45 ?
#           --> True
#            Predict {' <=50K': 1}
#           --> False
#            Predict {' >50K': 1}
#      --> False
#       Predict {' <=50K': 9}
#  --> False
#   Is capital_gain >= 5178 ?
#   --> True
#    Is relationship ==  Other-relative ?
#    --> True
#     Predict {' <=50K': 1}
#    --> False
#     Predict {' >50K': 49}
#   --> False
#    Is capital_loss >= 1848 ?
#    --> True
#     Is capital_loss >= 2042 ?
#     --> True
#      Is capital_loss >= 2174 ?
#      --> True
#       Predict {' >50K': 2}
#      --> False
#       Predict {' <=50K': 6}
#     --> False
#      Predict {' >50K': 24}
#    --> False
#     Is age >= 31 ?
#     --> True
#      Is education_num >= 8 ?
#      --> True
#       Is age >= 62 ?
#       --> True
#        Is native_country ==  Philippines ?
#        --> True
#         Predict {' >50K': 1}
#        --> False
#         Is fnlwgt >= 473748 ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Is age >= 76 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Predict {' <=50K': 43}
#       --> False
#        Is fnlwgt >= 116852 ?
#        --> True
#         Is occupation ==  Tech-support ?
#         --> True
#          Is capital_gain >= 5013 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 12}
#         --> False
#          Is occupation ==  Exec-managerial ?
#          --> True
#           Is workclass ==  Self-emp-not-inc ?
#           --> True
#            Is age >= 58 ?
#            --> True
#             Is hours_per_week >= 60 ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 1}
#            --> False
#             Predict {' <=50K': 8}
#           --> False
#            Is age >= 38 ?
#            --> True
#             Is education ==  Some-college ?
#             --> True
#              Predict {' >50K': 9}
#             --> False
#              Is sex ==  Male ?
#              --> True
#               Is fnlwgt >= 332355 ?
#               --> True
#                Is hours_per_week >= 50 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 3}
#               --> False
#                Is fnlwgt >= 170562 ?
#                --> True
#                 Is race ==  Black ?
#                 --> True
#                  Is fnlwgt >= 313022 ?
#                  --> True
#                   Predict {' >50K': 1}
#                  --> False
#                   Predict {' <=50K': 1}
#                 --> False
#                  Predict {' >50K': 6}
#                --> False
#                 Predict {' <=50K': 5, ' >50K': 4}
#              --> False
#               Predict {' >50K': 7}
#            --> False
#             Is hours_per_week >= 60 ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Is workclass ==  Federal-gov ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Is education_num >= 10 ?
#               --> True
#                Predict {' <=50K': 4}
#               --> False
#                Is fnlwgt >= 170718 ?
#                --> True
#                 Is age >= 32 ?
#                 --> True
#                  Predict {' <=50K': 4}
#                 --> False
#                  Predict {' >50K': 1}
#                --> False
#                 Predict {' >50K': 1}
#          --> False
#           Is occupation ==  Farming-fishing ?
#           --> True
#            Is age >= 32 ?
#            --> True
#             Is hours_per_week >= 98 ?
#             --> True
#              Is fnlwgt >= 195462 ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 2}
#             --> False
#              Predict {' <=50K': 16}
#            --> False
#             Predict {' >50K': 1}
#           --> False
#            Is race ==  White ?
#            --> True
#             Is age >= 57 ?
#             --> True
#              Is fnlwgt >= 232308 ?
#              --> True
#               Is age >= 60 ?
#               --> True
#                Predict {' >50K': 4}
#               --> False
#                Predict {' <=50K': 2}
#              --> False
#               Predict {' <=50K': 16}
#             --> False
#              Is fnlwgt >= 165767 ?
#              --> True
#               Is capital_gain >= 4386 ?
#               --> True
#                Is hours_per_week >= 50 ?
#                --> True
#                 Predict {' <=50K': 1}
#                --> False
#                 Predict {' >50K': 4}
#               --> False
#                Is fnlwgt >= 168232 ?
#                --> True
#                 Is fnlwgt >= 170769 ?
#                 --> True
#                  Is occupation ==  Transport-moving ?
#                  --> True
#                   Is hours_per_week >= 60 ?
#                   --> True
#                    Is education_num >= 10 ?
#                    --> True
#                     Predict {' >50K': 2}
#                    --> False
#                     Predict {' <=50K': 3}
#                   --> False
#                    Predict {' <=50K': 10}
#                  --> False
#                   Is hours_per_week >= 60 ?
#                   --> True
#                    Is hours_per_week >= 75 ?
#                    --> True
#                     Predict {' >50K': 1}
#                    --> False
#                     Is fnlwgt >= 383493 ?
#                     --> True
#                      Is hours_per_week >= 70 ?
#                      --> True
#                       Predict {' <=50K': 1}
#                      --> False
#                       Predict {' >50K': 1}
#                     --> False
#                      Predict {' <=50K': 11}
#                   --> False
#                    Is workclass ==  Self-emp-inc ?
#                    --> True
#                     Predict {' >50K': 3}
#                    --> False
#                     Is hours_per_week >= 56 ?
#                     --> True
#                      Predict {' >50K': 2}
#                     --> False
#                      Is hours_per_week >= 20 ?
#                      --> True
#                       Is workclass ==  State-gov ?
#                       --> True
#                        Predict {' <=50K': 5}
#                       --> False
#                        Is fnlwgt >= 375675 ?
#                        --> True
#                         Is fnlwgt >= 403550 ?
#                         --> True
#                          Is education_num >= 11 ?
#                          --> True
#                           Predict {' >50K': 2}
#                          --> False
#                           Predict {' <=50K': 3}
#                         --> False
#                          Predict {' >50K': 5}
#                        --> False
#                         Predict {' <=50K': 83, ' >50K': 51}
#                      --> False
#                       Predict {' <=50K': 5}
#                 --> False
#                  Is education_num >= 12 ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Predict {' >50K': 4}
#                --> False
#                 Predict {' <=50K': 6}
#              --> False
#               Is fnlwgt >= 164190 ?
#               --> True
#                Predict {' >50K': 4}
#               --> False
#                Is age >= 56 ?
#                --> True
#                 Predict {' >50K': 3}
#                --> False
#                 Is hours_per_week >= 25 ?
#                 --> True
#                  Is occupation ==  Sales ?
#                  --> True
#                   Is age >= 46 ?
#                   --> True
#                    Is age >= 54 ?
#                    --> True
#                     Predict {' >50K': 2}
#                    --> False
#                     Predict {' <=50K': 3}
#                   --> False
#                    Is workclass ==  Local-gov ?
#                    --> True
#                     Predict {' <=50K': 1}
#                    --> False
#                     Predict {' >50K': 6}
#                  --> False
#                   Is hours_per_week >= 60 ?
#                   --> True
#                    Predict {' <=50K': 6, ' >50K': 1}
#                   --> False
#                    Is hours_per_week >= 30 ?
#                    --> True
#                     Is capital_loss >= 1672 ?
#                     --> True
#                      Predict {' <=50K': 2}
#                     --> False
#                      Is fnlwgt >= 128002 ?
#                      --> True
#                       Is fnlwgt >= 140516 ?
#                       --> True
#                        Is age >= 50 ?
#                        --> True
#                         Is hours_per_week >= 40 ?
#                         --> True
#                          Predict {' >50K': 7}
#                         --> False
#                          Predict {' <=50K': 1}
#                        --> False
#                         Is education_num >= 10 ?
#                         --> True
#                          Is fnlwgt >= 159187 ?
#                          --> True
#                           Predict {' >50K': 1, ' <=50K': 1}
#                          --> False
#                           Predict {' <=50K': 5}
#                         --> False
#                          Predict {' >50K': 5, ' <=50K': 3}
#                       --> False
#                        Is workclass ==  Local-gov ?
#                        --> True
#                         Predict {' >50K': 1}
#                        --> False
#                         Is fnlwgt >= 133060 ?
#                         --> True
#                          Predict {' <=50K': 7}
#                         --> False
#                          Is hours_per_week >= 45 ?
#                          --> True
#                           Predict {' <=50K': 1}
#                          --> False
#                           Predict {' >50K': 1}
#                      --> False
#                       Is education_num >= 10 ?
#                       --> True
#                        Predict {' >50K': 5}
#                       --> False
#                        Predict {' >50K': 3, ' <=50K': 4}
#                    --> False
#                     Predict {' <=50K': 2}
#                 --> False
#                  Predict {' >50K': 2}
#            --> False
#             Is hours_per_week >= 48 ?
#             --> True
#              Predict {' <=50K': 5, ' >50K': 7}
#             --> False
#              Is workclass ==  Federal-gov ?
#              --> True
#               Predict {' >50K': 2}
#              --> False
#               Is capital_gain >= 4386 ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Is occupation ==  Protective-serv ?
#                --> True
#                 Is hours_per_week >= 40 ?
#                 --> True
#                  Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 1}
#                --> False
#                 Is occupation ==  Sales ?
#                 --> True
#                  Is education_num >= 10 ?
#                  --> True
#                   Predict {' <=50K': 2}
#                  --> False
#                   Is fnlwgt >= 220049 ?
#                   --> True
#                    Predict {' >50K': 1}
#                   --> False
#                    Predict {' <=50K': 1}
#                 --> False
#                  Predict {' <=50K': 30}
#        --> False
#         Is age >= 59 ?
#         --> True
#          Is hours_per_week >= 50 ?
#          --> True
#           Predict {' <=50K': 2}
#          --> False
#           Is occupation ==  Craft-repair ?
#           --> True
#            Is hours_per_week >= 43 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Is fnlwgt >= 109638 ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 2}
#           --> False
#            Is occupation ==  Prof-specialty ?
#            --> True
#             Is hours_per_week >= 40 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 1}
#            --> False
#             Predict {' >50K': 5}
#         --> False
#          Is age >= 37 ?
#          --> True
#           Is occupation ==  Adm-clerical ?
#           --> True
#            Is age >= 49 ?
#            --> True
#             Is fnlwgt >= 87928 ?
#             --> True
#              Is fnlwgt >= 92463 ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 2}
#            --> False
#             Predict {' >50K': 4}
#           --> False
#            Is fnlwgt >= 34377 ?
#            --> True
#             Is fnlwgt >= 36177 ?
#             --> True
#              Is age >= 38 ?
#              --> True
#               Is hours_per_week >= 56 ?
#               --> True
#                Predict {' <=50K': 11}
#               --> False
#                Is hours_per_week >= 54 ?
#                --> True
#                 Predict {' >50K': 2}
#                --> False
#                 Is workclass ==  State-gov ?
#                 --> True
#                  Predict {' >50K': 1}
#                 --> False
#                  Is hours_per_week >= 32 ?
#                  --> True
#                   Is occupation ==  Prof-specialty ?
#                   --> True
#                    Predict {' <=50K': 2, ' >50K': 3}
#                   --> False
#                    Is fnlwgt >= 111067 ?
#                    --> True
#                     Predict {' <=50K': 6}
#                    --> False
#                     Is fnlwgt >= 110373 ?
#                     --> True
#                      Predict {' >50K': 2}
#                     --> False
#                      Is hours_per_week >= 43 ?
#                      --> True
#                       Is workclass ==  Self-emp-inc ?
#                       --> True
#                        Is occupation ==  Farming-fishing ?
#                        --> True
#                         Predict {' <=50K': 1}
#                        --> False
#                         Predict {' >50K': 1}
#                       --> False
#                        Predict {' <=50K': 12}
#                      --> False
#                       Is workclass ==  Private ?
#                       --> True
#                        Is age >= 54 ?
#                        --> True
#                         Predict {' >50K': 2}
#                        --> False
#                         Is capital_gain >= 3103 ?
#                         --> True
#                          Predict {' >50K': 1}
#                         --> False
#                          Is age >= 46 ?
#                          --> True
#                           Predict {' <=50K': 3}
#                          --> False
#                           Predict {' <=50K': 10, ' >50K': 5}
#                       --> False
#                        Is occupation ==  Exec-managerial ?
#                        --> True
#                         Predict {' >50K': 1}
#                        --> False
#                         Predict {' <=50K': 9}
#                  --> False
#                   Predict {' <=50K': 8}
#              --> False
#               Is occupation ==  Craft-repair ?
#               --> True
#                Predict {' <=50K': 2}
#               --> False
#                Predict {' >50K': 4}
#             --> False
#              Predict {' >50K': 2}
#            --> False
#             Predict {' <=50K': 17}
#          --> False
#           Is hours_per_week >= 55 ?
#           --> True
#            Is fnlwgt >= 80145 ?
#            --> True
#             Predict {' <=50K': 4}
#            --> False
#             Is hours_per_week >= 80 ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 2}
#           --> False
#            Is occupation ==  Prof-specialty ?
#            --> True
#             Is education_num >= 10 ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 3}
#            --> False
#             Is occupation ==  Sales ?
#             --> True
#              Is hours_per_week >= 50 ?
#              --> True
#               Is native_country ==  Taiwan ?
#               --> True
#                Predict {' <=50K': 1}
#               --> False
#                Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 4}
#             --> False
#              Predict {' <=50K': 34}
#      --> False
#       Is native_country ==  Canada ?
#       --> True
#        Predict {' >50K': 1}
#       --> False
#        Is occupation ==  Transport-moving ?
#        --> True
#         Is education ==  10th ?
#         --> True
#          Is hours_per_week >= 30 ?
#          --> True
#           Predict {' >50K': 3}
#          --> False
#           Predict {' <=50K': 1}
#         --> False
#          Is fnlwgt >= 44246 ?
#          --> True
#           Predict {' <=50K': 8}
#          --> False
#           Predict {' >50K': 1}
#        --> False
#         Is occupation ==  Tech-support ?
#         --> True
#          Is hours_per_week >= 40 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Predict {' <=50K': 1}
#         --> False
#          Is fnlwgt >= 188644 ?
#          --> True
#           Is workclass ==  Self-emp-inc ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Predict {' <=50K': 60}
#          --> False
#           Is fnlwgt >= 185385 ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Is age >= 37 ?
#            --> True
#             Is sex ==  Female ?
#             --> True
#              Is hours_per_week >= 40 ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 1}
#             --> False
#              Is occupation ==  Exec-managerial ?
#              --> True
#               Is education ==  9th ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 3}
#              --> False
#               Is education_num >= 7 ?
#               --> True
#                Is age >= 60 ?
#                --> True
#                 Predict {' >50K': 1}
#                --> False
#                 Predict {' <=50K': 6}
#               --> False
#                Predict {' <=50K': 29}
#            --> False
#             Is fnlwgt >= 90273 ?
#             --> True
#              Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 2}
#     --> False
#      Is occupation ==  Prof-specialty ?
#      --> True
#       Is age >= 27 ?
#       --> True
#        Is hours_per_week >= 45 ?
#        --> True
#         Predict {' <=50K': 1}
#        --> False
#         Is education_num >= 11 ?
#         --> True
#          Is sex ==  Male ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 1}
#         --> False
#          Predict {' >50K': 3}
#       --> False
#        Predict {' <=50K': 2}
#      --> False
#       Is native_country ==  Ireland ?
#       --> True
#        Predict {' >50K': 1}
#       --> False
#        Is native_country ==  Germany ?
#        --> True
#         Predict {' >50K': 1}
#        --> False
#         Is fnlwgt >= 209934 ?
#         --> True
#          Predict {' <=50K': 58}
#         --> False
#          Is fnlwgt >= 207064 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is education_num >= 12 ?
#           --> True
#            Predict {' >50K': 2, ' <=50K': 3}
#           --> False
#            Is occupation ==  Sales ?
#            --> True
#             Is fnlwgt >= 154966 ?
#             --> True
#              Is hours_per_week >= 50 ?
#              --> True
#               Predict {' >50K': 2}
#              --> False
#               Is hours_per_week >= 35 ?
#               --> True
#                Predict {' <=50K': 2}
#               --> False
#                Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 5}
#            --> False
#             Is hours_per_week >= 60 ?
#             --> True
#              Predict {' <=50K': 4, ' >50K': 2}
#             --> False
#              Is fnlwgt >= 37215 ?
#              --> True
#               Is occupation ==  Machine-op-inspct ?
#               --> True
#                Is age >= 29 ?
#                --> True
#                 Is fnlwgt >= 151773 ?
#                 --> True
#                  Is fnlwgt >= 154843 ?
#                  --> True
#                   Is education ==  HS-grad ?
#                   --> True
#                    Is fnlwgt >= 177413 ?
#                    --> True
#                     Predict {' >50K': 1}
#                    --> False
#                     Predict {' <=50K': 1}
#                   --> False
#                    Predict {' <=50K': 2}
#                  --> False
#                   Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 3}
#                --> False
#                 Predict {' <=50K': 9}
#               --> False
#                Is occupation ==  Exec-managerial ?
#                --> True
#                 Is education ==  Some-college ?
#                 --> True
#                  Is hours_per_week >= 42 ?
#                  --> True
#                   Predict {' <=50K': 2}
#                  --> False
#                   Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 6}
#                --> False
#                 Predict {' <=50K': 59}
#              --> False
#               Is occupation ==  Handlers-cleaners ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 2}
# --> False
#  Is capital_gain >= 7430 ?
#  --> True
#   Is age >= 22 ?
#   --> True
#    Predict {' >50K': 42}
#   --> False
#    Predict {' <=50K': 1}
#  --> False
#   Is education_num >= 15 ?
#   --> True
#    Is age >= 33 ?
#    --> True
#     Is marital_status ==  Divorced ?
#     --> True
#      Predict {' <=50K': 3}
#     --> False
#      Is workclass ==  State-gov ?
#      --> True
#       Is native_country ==  Italy ?
#       --> True
#        Predict {' >50K': 1}
#       --> False
#        Predict {' <=50K': 2}
#      --> False
#       Predict {' >50K': 10}
#    --> False
#     Predict {' <=50K': 4}
#   --> False
#    Is capital_loss >= 2559 ?
#    --> True
#     Predict {' >50K': 5}
#    --> False
#     Is education_num >= 13 ?
#     --> True
#      Is age >= 47 ?
#      --> True
#       Is hours_per_week >= 40 ?
#       --> True
#        Is age >= 49 ?
#        --> True
#         Is occupation ==  Exec-managerial ?
#         --> True
#          Is hours_per_week >= 45 ?
#          --> True
#           Predict {' >50K': 4}
#          --> False
#           Is age >= 53 ?
#           --> True
#            Predict {' <=50K': 3}
#           --> False
#            Is sex ==  Male ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 1}
#         --> False
#          Is fnlwgt >= 132930 ?
#          --> True
#           Is fnlwgt >= 147653 ?
#           --> True
#            Is fnlwgt >= 216475 ?
#            --> True
#             Is occupation ==  Adm-clerical ?
#             --> True
#              Is relationship ==  Unmarried ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 2}
#             --> False
#              Is occupation ==  Sales ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Is marital_status ==  Separated ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 9}
#            --> False
#             Predict {' <=50K': 8}
#           --> False
#            Predict {' >50K': 2}
#          --> False
#           Predict {' <=50K': 5}
#        --> False
#         Predict {' <=50K': 3, ' >50K': 7}
#       --> False
#        Predict {' <=50K': 12}
#      --> False
#       Is age >= 29 ?
#       --> True
#        Is hours_per_week >= 50 ?
#        --> True
#         Is occupation ==  Sales ?
#         --> True
#          Is fnlwgt >= 196491 ?
#          --> True
#           Predict {' <=50K': 2}
#          --> False
#           Is relationship ==  Own-child ?
#           --> True
#            Predict {' <=50K': 1}
#           --> False
#            Predict {' >50K': 3}
#         --> False
#          Is fnlwgt >= 198183 ?
#          --> True
#           Is age >= 37 ?
#           --> True
#            Predict {' <=50K': 5}
#           --> False
#            Is fnlwgt >= 381645 ?
#            --> True
#             Predict {' <=50K': 1}
#            --> False
#             Predict {' >50K': 3}
#          --> False
#           Predict {' <=50K': 15}
#        --> False
#         Is capital_gain >= 4934 ?
#         --> True
#          Is hours_per_week >= 48 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 1}
#         --> False
#          Is relationship ==  Not-in-family ?
#          --> True
#           Is age >= 43 ?
#           --> True
#            Predict {' >50K': 3, ' <=50K': 12}
#           --> False
#            Is age >= 34 ?
#            --> True
#             Is fnlwgt >= 316211 ?
#             --> True
#              Is sex ==  Male ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Predict {' <=50K': 3}
#             --> False
#              Predict {' <=50K': 32}
#            --> False
#             Is fnlwgt >= 183009 ?
#             --> True
#              Predict {' <=50K': 14}
#             --> False
#              Is occupation ==  Prof-specialty ?
#              --> True
#               Is sex ==  Male ?
#               --> True
#                Predict {' >50K': 2}
#               --> False
#                Predict {' <=50K': 1}
#              --> False
#               Is occupation ==  Tech-support ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 6}
#          --> False
#           Predict {' <=50K': 32}
#       --> False
#        Is capital_loss >= 2231 ?
#        --> True
#         Predict {' >50K': 1}
#        --> False
#         Is native_country ==  Philippines ?
#         --> True
#          Is capital_loss >= 1092 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 1}
#         --> False
#          Predict {' <=50K': 107}
#     --> False
#      Is native_country ==  Italy ?
#      --> True
#       Predict {' >50K': 1}
#      --> False
#       Is marital_status ==  Divorced ?
#       --> True
#        Is age >= 53 ?
#        --> True
#         Is native_country ==  Puerto-Rico ?
#         --> True
#          Predict {' >50K': 1}
#         --> False
#          Is race ==  Other ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is occupation ==  Tech-support ?
#           --> True
#            Predict {' >50K': 1}
#           --> False
#            Is occupation ==  Exec-managerial ?
#            --> True
#             Is sex ==  Male ?
#             --> True
#              Is education ==  Some-college ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 2}
#             --> False
#              Predict {' <=50K': 3}
#            --> False
#             Is age >= 54 ?
#             --> True
#              Is occupation ==  Machine-op-inspct ?
#              --> True
#               Is fnlwgt >= 365683 ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 1}
#              --> False
#               Is age >= 69 ?
#               --> True
#                Is age >= 70 ?
#                --> True
#                 Predict {' <=50K': 6}
#                --> False
#                 Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 47}
#             --> False
#              Is occupation ==  Transport-moving ?
#              --> True
#               Predict {' >50K': 1}
#              --> False
#               Is hours_per_week >= 48 ?
#               --> True
#                Is hours_per_week >= 50 ?
#                --> True
#                 Predict {' <=50K': 1}
#                --> False
#                 Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 3}
#        --> False
#         Is fnlwgt >= 20469 ?
#         --> True
#          Is education ==  Some-college ?
#          --> True
#           Is occupation ==  Craft-repair ?
#           --> True
#            Is age >= 32 ?
#            --> True
#             Predict {' >50K': 3}
#            --> False
#             Predict {' <=50K': 3}
#           --> False
#            Is race ==  Amer-Indian-Eskimo ?
#            --> True
#             Is occupation ==  Protective-serv ?
#             --> True
#              Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 2}
#            --> False
#             Is fnlwgt >= 179580 ?
#             --> True
#              Is fnlwgt >= 183096 ?
#              --> True
#               Is hours_per_week >= 44 ?
#               --> True
#                Is hours_per_week >= 45 ?
#                --> True
#                 Is occupation ==  Exec-managerial ?
#                 --> True
#                  Is hours_per_week >= 55 ?
#                  --> True
#                   Predict {' <=50K': 1}
#                  --> False
#                   Predict {' >50K': 1}
#                 --> False
#                  Predict {' <=50K': 6}
#                --> False
#                 Predict {' >50K': 1}
#               --> False
#                Predict {' <=50K': 21}
#              --> False
#               Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 41}
#          --> False
#           Is occupation ==  Prof-specialty ?
#           --> True
#            Is education ==  Assoc-voc ?
#            --> True
#             Is race ==  Amer-Indian-Eskimo ?
#             --> True
#              Predict {' <=50K': 1}
#             --> False
#              Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 12}
#           --> False
#            Is race ==  Black ?
#            --> True
#             Is occupation ==  Exec-managerial ?
#             --> True
#              Is hours_per_week >= 50 ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 1}
#             --> False
#              Predict {' <=50K': 17}
#            --> False
#             Predict {' <=50K': 159}
#         --> False
#          Is hours_per_week >= 84 ?
#          --> True
#           Predict {' <=50K': 1}
#          --> False
#           Predict {' >50K': 1}
#       --> False
#        Is hours_per_week >= 47 ?
#        --> True
#         Is hours_per_week >= 48 ?
#         --> True
#          Is capital_loss >= 2258 ?
#          --> True
#           Predict {' >50K': 1}
#          --> False
#           Is fnlwgt >= 455995 ?
#           --> True
#            Is hours_per_week >= 65 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 1}
#           --> False
#            Is occupation ==  Sales ?
#            --> True
#             Is relationship ==  Unmarried ?
#             --> True
#              Is hours_per_week >= 66 ?
#              --> True
#               Predict {' <=50K': 1}
#              --> False
#               Predict {' >50K': 2}
#             --> False
#              Is education ==  Some-college ?
#              --> True
#               Predict {' <=50K': 5, ' >50K': 1}
#              --> False
#               Predict {' <=50K': 10}
#            --> False
#             Is occupation ==  Protective-serv ?
#             --> True
#              Predict {' <=50K': 2, ' >50K': 1}
#             --> False
#              Is education_num >= 8 ?
#              --> True
#               Predict {' <=50K': 82}
#              --> False
#               Is fnlwgt >= 323605 ?
#               --> True
#                Predict {' >50K': 1}
#               --> False
#                Is fnlwgt >= 38772 ?
#                --> True
#                 Predict {' <=50K': 16}
#                --> False
#                 Predict {' >50K': 1}
#         --> False
#          Predict {' >50K': 1}
#        --> False
#         Is occupation ==  Exec-managerial ?
#         --> True
#          Is age >= 54 ?
#          --> True
#           Is sex ==  Male ?
#           --> True
#            Is education_num >= 10 ?
#            --> True
#             Predict {' >50K': 1}
#            --> False
#             Predict {' <=50K': 1}
#           --> False
#            Predict {' <=50K': 5}
#          --> False
#           Predict {' <=50K': 31}
#         --> False
#          Predict {' <=50K': 865}
